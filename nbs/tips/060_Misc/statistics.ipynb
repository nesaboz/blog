# %% [markdown]
# # Statistics

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Correlation
#
# Paerson coefficient between columns is a way of measuring a linear correlation. It is a number between –1 and 1 that measures the strength and direction of the relationship between two variables:
# $\rho_{X,Y} = \frac{cov(X,Y)}{\sigma_X \sigma_Y} = \frac{(X,Y)}{\sigma_X \sigma_Y}$
#
# ![image.png](assets/Correlation_examples2.jpg)

# %% [markdown]
# # Label Encoder
# `LabelEncoder` can be used to normalize labels.
#
# ```
# >>> from sklearn import preprocessing
# >>> le = preprocessing.LabelEncoder()
# >>> le.fit([1, 2, 2, 6])
# LabelEncoder()
# >>> le.classes_
# array([1, 2, 6])
# >>> le.transform([1, 1, 2, 6])
# array([0, 0, 1, 2]...)
# >>> le.inverse_transform([0, 0, 1, 2])
# array([1, 1, 2, 6])
# ```

# %% [markdown]
# # Convert type
#
# `df[column].apply(str)`
# `df[column].apply(float)`

# %% [markdown]
# # Describe

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(10, 5), columns=['a', 'b', 'c', 'd', 'e'])
df.describe()
# Out:
#                a          b          c          d          e
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   -0.112457  -0.459562   0.335918  -0.158162  -0.502749
# std     0.961196   1.512322   0.503173   0.954076   0.760147
# min    -2.436000  -3.371129  -0.274669  -2.372165  -2.245261
# 25%    -0.328423  -0.928391  -0.086974  -0.543056  -0.792348
# 50%    -0.035455  -0.338360   0.304707   0.105834  -0.328568
# 75%     0.233523   0.316508   0.725202   0.301655  -0.209429
# max     1.292070   1.533545   1.096466   0.938239   0.509084

# %% [markdown]
# # Missing values visualization

# %%
df.iloc[1,2] = np.nan
df.iloc[3,4] = np.nan

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
df['c'].fillna(0, inplace=True)

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # Counter

# %%
df.dtypes
# Out:
# a    float64
# b    float64
# c    float64
# d    float64
# e    float64
# dtype: object

# %%
df.a = df.a.apply(str)

# %%
df.dtypes
# Out:
# a     object
# b    float64
# c    float64
# d    float64
# e    float64
# dtype: object

# %%
from collections import Counter
Counter(df.dtypes)
# Out:
# Counter({dtype('O'): 1, dtype('float64'): 4})

# %% [markdown]
# # Skew

# %%
from scipy.stats import skew

# %%
def plot_skew(array):
    fig, axs = plt.subplots(1,2, figsize=(10,3))
    axs[0].plot(array)
    values, ranges = np.histogram(array, 100)
    axs[1].plot(ranges[:-1], values)
    axs[0].set_title(f'Skew: {skew(array)}')
    axs[1].set_title('Distribution')
    plt.show()

# %%
np.random.seed(42)
plot_skew(np.random.randn(10))
plot_skew(np.random.randn(1000))
plot_skew(np.random.randn(1000000))
plot_skew(np.arange(1000))

# %% [markdown]
# # Box-Cox transformation

# %%
from scipy.special import boxcox1p
from scipy.special import boxcox

# %% [markdown]
# Box-Cox transformation is a way to transform non-normal dependent variables into a normal shape.

# %%
a = np.random.beta(1, 3, 5000)

# %%
plot_skew(a)
plot_skew(boxcox(a, 0.5))

# %% [markdown]
# # One-hot encoding

# %%
s = pd.Series(list('abca'))
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: object

# %%
pd.get_dummies(s)
# Out:
#    a  b  c
# 0  1  0  0
# 1  0  1  0
# 2  0  0  1
# 3  1  0  0

# %% [markdown]
# # Exponential

# %% [markdown]
# Calculate ``exp(x) - 1`` for all elements in the array: `np.expm1`
